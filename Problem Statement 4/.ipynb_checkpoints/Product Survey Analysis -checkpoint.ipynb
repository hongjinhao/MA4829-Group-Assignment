# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics
# Out:
# C:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
car_data = pd.read_excel('SURVEY_RESULTS_2024.xlsx')
car_data.head()
# Out:
#   Which age group do you belong to? What is your gender?  \
# 0                             20-30                 Male
# 1                             20-30               Female
# 2                             20-30                 Male
# 3                             20-30               Female
# 4                             20-30                 Male
#
#           Which category do you currently belong to?  \
# 0  Do not own a car, but planning to purchase in ...
# 1  Do not own a car, but planning to purchase in ...
# 2  Do not own a car, but planning to purchase in ...
# 3  Do not own a car, but planning to purchase in ...
# 4  Do not own a car, but planning to purchase in ...
#
#   Which of the following best describes you?  \
# 0                                     Single
# 1                                     Single
# 2                                     Single
# 3                                     Single
# 4                                     Single
#
# ...

# %%
headers = ["age_group", "gender", "background", "rs_status", "buyer_factor", "custom_car_likelihood",
           "ext_components", "int_components","customisation_spending", "custom_car_interest", 
           "price_willingness", "design_exp","design_ideas"]
car_data.columns = headers
car_data.head()
# Out:
#   age_group  gender                                         background  \
# 0     20-30    Male  Do not own a car, but planning to purchase in ...
# 1     20-30  Female  Do not own a car, but planning to purchase in ...
# 2     20-30    Male  Do not own a car, but planning to purchase in ...
# 3     20-30  Female  Do not own a car, but planning to purchase in ...
# 4     20-30    Male  Do not own a car, but planning to purchase in ...
#
#   rs_status                                       buyer_factor  \
# 0    Single      Price;Functionality;Size;Customisable options
# 1    Single  Price;Brand name;Aesthetics;Technological feat...
# 2    Single      Aesthetics;Functionality;Customisable options
# 3    Single  Price;Brand name;Aesthetics;Technological feat...
# 4    Single  Price;Brand name;Aesthetics;Technological feat...
#
#   custom_car_likelihood                                  ext_components  \
# 0           Very likely                                         Grilles
# ...

# %%
print("Data type : ", type(car_data))
print("Data dims : ", car_data.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (50, 13)

# %%
print(car_data.dtypes)
# Out:
# age_group                 object
# gender                    object
# background                object
# rs_status                 object
# buyer_factor              object
# custom_car_likelihood     object
# ext_components            object
# int_components            object
# customisation_spending    object
# custom_car_interest       object
# price_willingness         object
# design_exp                object
# design_ideas              object
# dtype: object

# %%
car_data.describe()
# Out:
#        age_group gender                                         background  \
# count         50     50                                                 50
# unique         4      3                                                  3
# top        20-30   Male  Do not own a car, but planning to purchase in ...
# freq          41     32                                                 36
#
#        rs_status                                       buyer_factor  \
# count         50                                                 49
# unique         3                                                 37
# top       Single  Price;Brand name;Aesthetics;Technological feat...
# freq          38                                                  5
#
#        custom_car_likelihood ext_components int_components  \
# count                     50             49             50
# unique                     3             23             16
# top              Very likely         Wheels      Dashboard
# ...

# %%
f = plt.figure(figsize=(12, 12))
sb.pairplot(data = car_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\JINHAO~1\AppData\Local\Temp/ipykernel_35024/3743751149.py in <module>
#       1 f = plt.figure(figsize=(12, 12))
# ----> 2 sb.pairplot(data = car_data)
#
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
# ...
